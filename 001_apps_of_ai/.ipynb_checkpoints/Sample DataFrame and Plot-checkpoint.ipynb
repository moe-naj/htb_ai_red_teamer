# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a sample DataFrame
data = pd.DataFrame({
    "column1": np.random.rand(100),  # 50 random values for column1
    "column2": np.random.rand(100) * 10  # 50 random values (multiplied by 10) for column2
})

# Display the first few rows
print(data.head())

# Create a scatter plot
plt.scatter(data["column1"], data["column2"])
plt.xlabel("Column 1")
plt.ylabel("Column 2")
plt.title("Scatter Plot")
plt.show()
# Out:
#     column1   column2
# 0  0.743324  5.452559
# 1  0.940971  5.577509
# 2  0.967545  1.360376
# 3  0.260578  2.796159
# 4  0.617441  7.876593
